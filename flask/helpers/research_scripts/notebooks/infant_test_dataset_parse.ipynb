# %%
import pandas as pd

# read data/infant_dataset_formatted.csv into a pandas dataframe
df = pd.read_csv('data/infant_dataset_formatted.csv')

# %%
df
# Out:
#    Study No, age, sex                     Presenting features\nHPO terms  \
# 0     0204301 \n9m\nM  [HP:0000568] Microphthalmos  [HP:0008538] Sens...
# 1     0204303 \n8m\nM   [HP:0004322] Short stature\n[HP:0000316] Hype...
# 2     0204317 \n1m\nM  [HP:0010783] Erythema  [HP:0007549] Desquamati...
# 3      0204319\n1m\nM                            [HP:0001250] Seizures\n
# 4     0204327 \n9m\nF  [HP:0001290] Generalized hypotonia \n[HP:00012...
# 5     0204334 \n2m\nF  [HP:0011001] Increased bone mineral density  [...
# 6     0204335 \n5m\nF  [HP:0001263] Global developmental delay  [HP:0...
# 7    0204426 \n0.7\nM  [HP:0001290] Generalized hypotonia \n[HP:00031...
# 8    0204436 \n18m\nM  [HP:0010864] Intellectual disability, severe\n...
# 9    0204428\n0.5m\nM                             [HP:0001250]\nSeizures
# 10    0204308 \n3m\nM  [HP:0000581] Blepharophimosis  [HP:0000414] Bu...
# 11    0204329 \n8M\nM  [HP:0001696] Situs inversus totalis\n[HP:00059...
# ...

# %%
len(df)
# Out:
# 47

# %%
df.iloc[0][2]
# Out:
# 'Microphthalmia syndromic 3 (#206900)\n\nSOX2\nChr3:g.181430628C>G, heterozygous\nNM_003106.3, NP_003097.1\nc.480C>G, p.(Tyr160*)\n'

# %%
# read data/test_formatted.csv into a pandas dataframe
df_test = pd.read_csv('data/test_formatted.csv')

# %%
df_test
# Out:
#      Study No, age, sex                     Presenting features\nHPO terms  \
# 0       0204301 \n9m\nM  [HP:0000568] Microphthalmos  [HP:0008538] Sens...
# 1       0204303 \n8m\nM   [HP:0004322] Short stature\n[HP:0000316] Hype...
# 2       0204317 \n1m\nM  [HP:0010783] Erythema  [HP:0007549] Desquamati...
# 3        0204319\n1m\nM                            [HP:0001250] Seizures\n
# 4       0204327 \n9m\nF  [HP:0001290] Generalized hypotonia \n[HP:00012...
# 5       0204334 \n2m\nF  [HP:0011001] Increased bone mineral density  [...
# 6       0204335 \n5m\nF  [HP:0001263] Global developmental delay  [HP:0...
# 7      0204426 \n0.7\nM  [HP:0001290] Generalized hypotonia \n[HP:00031...
# 8      0204436 \n18m\nM  [HP:0010864] Intellectual disability, severe\n...
# 9      0204428\n0.5m\nM                             [HP:0001250]\nSeizures
# 10  0204308 \nSW\n3m\nM  [HP:0000581] Blepharophimosis  [HP:0000414] Bu...
# ...

# %%
len(df_test)
# Out:
# 47
